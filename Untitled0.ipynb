# %% [markdown]
# <a href="https://colab.research.google.com/github/andreschavarro/Dataproject/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %config IPcompleter.greedy=True
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# ### cargara base de datos

# %%
from google.colab import files

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel('/content/drive/base_1.csv')
df.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-777e47dea94c> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_excel('/base_1.csv')
#       3 df.shape
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %% [markdown]
# # Sección nueva

# %%
from google.colab import files

# %%
load=files.upload()
# Out:
#      <input type="file" id="files-40258356-6a1a-44dd-a42a-487cd710de1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40258356-6a1a-44dd-a42a-487cd710de1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
datos = pd.read_csv('base_1.csv')
datos

# %%
datos.info()

# %%
pd.read_csv('/content/base_1.csv',sep=';')
# Out:
#         \nTag    \nLote \nUb.\nActual         \nSección\n  \
# 0     1417294  19778215      TEJIENDO              TEJIDO
# 1     1417301  19778539      TEJIENDO              TEJIDO
# 2     1418156  19773900      IGUALADO  EMPAQUE AUTOMATICO
# 3     1418254  19776474      TEJIENDO              TEJIDO
# 4     1418261  19775661     PENDXCERR              TEJIDO
# ...       ...       ...           ...                 ...
# 4160  8768450  19742245       SOLUTEX            TERCEROS
# 4161  5830057  19727930     TERCENVIO            TERCEROS
# 4162  7842725  19729949         CALLE            TERCEROS
# 4163  8863575  19729948         CALLE            TERCEROS
# 4164  1425402  19710184     SOBRANTES               OTROS
#
#                         \nZonaTejido \nFecha\nPrimera Ub \nHora\nPrimera Ub  \
# 0                                NaN          27/12/2022            2:07:00
# 1                                NaN          27/12/2022            7:56:00
# ...
